# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Kemesha Price**
#
# Data Scientist

# %% [markdown]
# *I'm interested in Data SCience because I have always had a love for Mathematics and Computer Science. I feel as though I get to genuinely enjoy both when I'm practicing my python programming and reviewing Statistics and Linear Algrebra*

# %% [markdown]
# ### In the cell below when the code is ran it asks the user for their favourite food and outputs "I love + (users inputted favourite food)".

# %%
fav_food = input("input favourite food: ")
print("I love " + fav_food)

# %% [markdown]
# 1. Bananas
# 2. ~Strawberries~
# 3. Grapes
# 4. Granola
#
# > The best smoothies usually have bananas, strawberries, oats or blueberries.
#
# | Fruit         | Colour        |Price $|
# | ------------- |---------------| ------|
# | Orange        | Orange        |  0.74 |
# | Tomato        | Red           |  0.78 |
# | Grapes        | Green/ Red    |  3/lb |
